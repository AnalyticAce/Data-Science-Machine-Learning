# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get(
    'https://www.sofascore.com/liverpool-tottenham-hotspur/IsU#11352644',
    headers= {
        "user-agent" : 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.31'
    }
)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.select('span[color="secondary.default"]')
#<span color="secondary.default" class="sc-jEACwC fMVwqC">2</span>
# Out:
# []

# %%
import requests

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'en-US,en-GB;q=0.9,en;q=0.8',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"0950997418"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Microsoft Edge";v="117", "Not;A=Brand";v="8", "Chromium";v="117"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Mobile Safari/537.36 Edg/117.0.2045.31',
}

response = requests.get('https://api.sofascore.com/api/v1/event/11352644/statistics', headers=headers)

# %%
response.status_code
# Out:
# 304

# %%
headers["If-Modified-Since"] = "Sat, 30 Sept 2023 00:00:00 GMT+1"
response = requests.get('https://api.sofascore.com/api/v1/event/11352644/statistics', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
stats = response.json()
stats
# Out:
# {'statistics': [{'period': 'ALL',
#    'groups': [{'groupName': 'Expected',
#      'statisticsItems': [{'name': 'Expected goals',
#        'home': '2.10',
#        'away': '1.34',
#        'compareCode': 1,
#        'statisticsType': 'positive',
#        'valueType': 'event',
#        'homeValue': 2.1,
#        'awayValue': 1.34},
#       {'name': 'Expected assists',
#        'home': '1.55',
#        'away': '0.89',
#        'compareCode': 1,
#        'statisticsType': 'positive',
#        'valueType': 'event',
#        'homeValue': 1.55,
#        'awayValue': 0.89}]},
#     {'groupName': 'Possession',
#      'statisticsItems': [{'name': 'Ball possession',
#        'home': '65%',
#        'away': '35%',
#        'compareCode': 1,
#        'statisticsType': 'positive',
#        'valueType': 'event',
#        'homeValue': 65,
#        'awayValue': 35}]},
#     {'groupName': 'Shots',
#      'statisticsItems': [{'name': 'Total shots',
#        'home': '24',
#        'away': '12',
# ...
